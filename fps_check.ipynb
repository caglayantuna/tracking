# %%
import cv2
video_path = "./data/Claire/A2_2L_P_03282024155531-0000.avi"

cap = cv2.VideoCapture(video_path)

# %%
fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
print(f"FPS: {fps}")
# Out:
# FPS: 59.65

# %%
video_path = "./data/black_larva/35_cbr_mel_A1_04-06-2024-06042024031526-0000.avi"
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS) or 25.0
print(f"FPS: {fps}")
# Out:
# FPS: 30.0
